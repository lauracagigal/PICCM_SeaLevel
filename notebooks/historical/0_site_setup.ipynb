# %% [markdown]
# # Site Setup
# Define site parameters once and save a reusable config file for all historical notebooks.

# %%
from pathlib import Path
import sys

sys.path.append("../../functions")
from sea_level import save_site_config, prepare_site_data

site_config = {
    "site_name": "Palau",
    "site_lon": 134.620,
    "site_lat": 7.340,
    "station_country_filter": "Palau",
    "selected_uhslc_id": None,
    "selected_station_name": None,
    "site_eez_shapefile": "../../data/Palau_EEZ/pw_eez_pol_april2022.shp",
    "start_date": "1993-01-01",
    "end_date": "2022-12-31",
    "cmems_bbox_override": None,
    "cmems_start_datetime": "1993-01-01T00:00:00",
    "cmems_end_datetime": "2025-04-30T23:59:59",
}

sea_level_data_dir = Path('../../data/sea_level')
site_config = prepare_site_data(site_config, sea_level_data_dir)

config_out = Path('../../data/sites/palau.json')
save_site_config(site_config, config_out)
print(f'Saved site config: {config_out.resolve()}')
site_config
# Out:
# Using cached CMEMS file: ../../data/sea_level/cmems_L4_SSH_0.125deg_1993_2025.nc
# Saved site config: /Users/laurac/Library/Mobile Documents/com~apple~CloudDocs/Projects/CC_indicators/PICCM/PICCM_SeaLevel/data/sites/palau.json
# {'site_name': 'Palau',
#  'site_lon': 134.62,
#  'site_lat': 7.34,
#  'station_country_filter': 'Palau',
#  'selected_uhslc_id': 7,
#  'selected_station_name': 'Malakal',
#  'site_eez_shapefile': '../../data/Palau_EEZ/pw_eez_pol_april2022.shp',
#  'start_date': '1993-01-01',
#  'end_date': '2022-12-31',
#  'cmems_bbox_override': None,
#  'cmems_start_datetime': '1993-01-01T00:00:00',
#  'cmems_end_datetime': '2025-04-30T23:59:59',
#  'station': 'Malakal',
#  'country': 'Palau',
#  'station_lon': 134.463,
#  'station_lat': 7.33,
#  'station_distance_km': 17.35040932937225,
#  'cmems_path': '../../data/sea_level/cmems_L4_SSH_0.125deg_1993_2025.nc',
#  'cmems_filename': 'cmems_L4_SSH_0.125deg_1993_2025.nc'}
